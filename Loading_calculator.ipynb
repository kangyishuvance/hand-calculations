# %%
import handcalcs.render
from handcalcs import render
import handcalcs
from math import pi, sqrt
from math import tan, radians, pi, exp

handcalcs.set_option("display_precision", 3)
handcalcs.set_option("underscore_subscripts", True)

# Custom symbol mappings (Python name -> LaTeX)
handcalcs.set_option("custom_symbols", {
    "Lambda_": r"\Lambda",   # uppercase Lambda (Λ)
    "lambda_": r"\lambda",  # lowercase lambda (λ) when using 'lambda_' in Python
    "V_dot": r"\dot{V}",
    "N_star": r"N^{*}",
})
print("Custom symbols registered.")
# Out:
# Custom symbols registered.

# %% [markdown]
# ### Line load from Area load

# %%
sw = 0 #KN/m2 
LL = 0 #KN/m2
SDL = 0 #KN/m2
load_width = 6 #m
q = (1.35*(sw+SDL) +1.5*LL)*load_width # KN/m load per unit length

# %% [markdown]
# ### Portal frame Moment

# %% [markdown]
# ![My Image](img/PortalFrameMoment.png)

# %%
# %%render params
# # Example usage (edit values)
# w = 10.0 #projected loading kN/m
# L = 10.0 #Total span m
# I_R = 1.0 #reference moment of inertia
# I_C = 1.5 * I_R   # preliminary assumption from the note
# h = 3.0 #height up to lowest rafter m
# f = 2 #rise of rafter m
# Out:
# \[
# \begin{aligned}
# w &= 10.000 \; \;\textrm{(projected loading kN/m)}
#  &L &= 10.000 \; \;\textrm{(Total span m)}
#  &I_{R} &= 1.000 \; \;\textrm{(reference moment of inertia)}
# \\[10pt]
#  I_{C} &= 1.500 \; \;\textrm{(preliminary assumption from the note)}
#  &h &= 3.000 \; \;\textrm{(height up to lowest rafter m)}
#  &f &= 2 \; \;\textrm{(rise of rafter m)}
# \\[10pt]
#  s &= 5.385 \; \;\textrm{(length of rafter m)}
# \end{aligned}
# \]

# %%
# %%render
# s = sqrt((L/2)**2 + f**2) #length of rafter m
# k   = (I_R * h) / (I_C * s)
# phi = f / h
# m   = 1 + phi
# B   = 2 * (k + 1) + m
# C   = 1 + 2 * m
# N   = B + m * C
# Out:
# \[
# \begin{aligned}
# s &= \sqrt { \left( \frac{ L }{ 2 } \right) ^{ 2 } + \left( f \right) ^{ 2 } }  = \sqrt { \left( \frac{ 10.000 }{ 2 } \right) ^{ 2 } + \left( 2 \right) ^{ 2 } } &= 5.385 \; \;\textrm{(length of rafter m)}
# \\[10pt]
# k &= \frac{ I_{R} \cdot h }{ I_{C} \cdot s }  = \frac{ 1.000 \cdot 3.000 }{ 1.500 \cdot 5.385 } &= 0.371
# \\[10pt]
# \phi &= \frac{ f }{ h }  = \frac{ 2 }{ 3.000 } &= 0.667
# \\[10pt]
# m &= 1 + \phi  = 1 + 0.667 &= 1.667
# \\[10pt]
# B &= 2 \cdot \left( k + 1 \right) + m  = 2 \cdot \left( 0.371 + 1 \right) + 1.667 &= 4.409
# \\[10pt]
# C &= 1 + 2 \cdot m  = 1 + 2 \cdot 1.667 &= 4.333
# \\[10pt]
# N &= B + m \cdot C  = 4.409 + 1.667 \cdot 4.333 &= 11.632
# \end{aligned}
# \]

# %%
# %%render
# M_E = w * L**2 * (3 + 5*m) / (16 * N)
# M_A = w * L**2 / 8 + m * M_E
# Out:
# \[
# \begin{aligned}
# M_{E} &= w \cdot \left( L \right) ^{ 2 } \cdot \frac{ 3 + 5 \cdot m }{ 16 \cdot N }  = 10.000 \cdot \left( 10.000 \right) ^{ 2 } \cdot \frac{ 3 + 5 \cdot 1.667 }{ 16 \cdot 11.632 } &= 60.897
# \\[10pt]
# M_{A} &= w \cdot \frac{ \left( L \right) ^{ 2 } }{ 8 } + m \cdot M_{E}  = 10.000 \cdot \frac{ \left( 10.000 \right) ^{ 2 } }{ 8 } + 1.667 \cdot 60.897 &= 226.495
# \end{aligned}
# \]

# %%
# %%render
# M_A = w * L**2 / 8
# Out:
# \[
# \begin{aligned}
# M_{A} &= w \cdot \frac{ \left( L \right) ^{ 2 } }{ 8 }  = 10.000 \cdot \frac{ \left( 10.000 \right) ^{ 2 } }{ 8 } &= 125.000
# \end{aligned}
# \]
