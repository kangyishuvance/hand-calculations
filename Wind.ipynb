# %%
from calc_setup import *
set_design_code('ec2_2004')
# Out:
# Calc environment ready.

# %% [markdown]
# # **General calculation**
# ### Calculation Report
# **Author:** Vance Kang
# **Date:** {{}}
# **Project No.:**
#
# ---
#
# ## Calculations

# %% [markdown]
# # -------------------------------------------------------
# ### Input parameters
# # -------------------------------------------------------

# %% [markdown]
# ![My Image](img/wind_excel.png)

# %%
# ---------------------------------------------------------
# Terrain & pressure coefficients
# ---------------------------------------------------------
def terrain_and_coeffs(
    terrain_category = 2,  # II
    z = 23.0,              # [m] height above terrain
    c_f = 1.20,            # [-] c_f or Σc_pe
    c_s = 1.00,            # [-]
    c_d = 1.00             # [-]
):
    C_s_C_d = c_s * c_d    # product Cs * Cd
    return terrain_category, z, c_f, C_s_C_d

# %%
# %%render params
# v_b_0 = 20.0,      # [m/s] fundamental basic wind velocity
# p     = 50.0,      # [years] return period
# c_dir = 1.00,      # [-] directional factor
# c_season = 1.00    # [-] season factor
# Out:
# $$
# \begin{aligned}
# v_{b_{0}} &= [20.000] \; \;\textrm{([m/s] fundamental basic wind velocity)}
#  &p &= [50.000] \; \;\textrm{([years] return period)}
#  &c_{dir} &= [1.000] \; \;\textrm{([-] directional factor)}
# \\
#  c_{season} &= 1.000 \; \;\textrm{([-] season factor)}
# \end{aligned}
# $$

# %%
# %%render
# z = 5*4 +3 #height of structure (m)
# q_p = 0.73 #Kpa from excel
# c_s = 1
# c_d = 1
# Out:
# $$
# \begin{aligned}
# z &= 5 \cdot 4 + 3 &= 23 \; \;\textrm{(height of structure (m))}
# \\
# q_{p} &= 0.730 \; \;\textrm{(Kpa from excel)}
# \\
# c_{s} &= 1 \;
# \\
# c_{d} &= 1 \;
# \end{aligned}
# $$

# %% [markdown]
# ![My Image](img/wind_table_76.png)

# %%
angle_rad = math.atan(300/4800)
angle_deg = math.degrees(angle_rad)
angle_deg
# Out:
# 3.576334374997351

# %% [markdown]
# ### Force method

# %% [markdown]
# ### pressure coeff for monopitch roof

# %%
# %%render
# c_f = -1 #upwards
# F_w = c_s*c_d*c_f*q_p
# roof_area = 4.8 * 6 #m2
# F_total = F_w * roof_area
# F_support = F_total / 4
# Out:
# \[
# \begin{aligned}
# c_{f} &= -1 \; \;\textrm{(upwards)}
# \\[10pt]
# F_{w} &= c_{s} \cdot c_{d} \cdot c_{f} \cdot q_{p}  = 1 \cdot 1 \cdot -1 \cdot 0.730 &= -0.730
# \\[10pt]
# \mathrm{roof}_{area} &= 4.8 \cdot 6 &= 28.800 \; \;\textrm{(m2)}
# \\[10pt]
# F_{total} &= F_{w} \cdot \mathrm{roof}_{area}  = -0.730 \cdot 28.800 &= -21.024
# \\[10pt]
# F_{support} &= \frac{ F_{total} }{ 4 }  = \frac{ -21.024 }{ 4 } &= -5.256
# \end{aligned}
# \]
